# %% [markdown]
# <a href="https://colab.research.google.com/github/DenisKanzeparov/workout/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Ivy', 'Jack'],
    'grade': ['Senior', 'Junior', 'Middle', 'Senior', 'Junior',
              'Middle', 'Senior', 'Senior', 'Middle', 'Junior'],
    'location': ['RU', 'AU', 'US', 'RU', 'JP', 'RU', 'US', 'US', 'RU', 'JP'],
    'salary': [700, 45, 96, 750, 50, 120, 800, 7200, 180, 71],
    'hours_worked': [16, 10, 15, 65, 40, 20, 70, 175, 50, 145]
}

data = pd.DataFrame(data)

data
# Out:
#       name   grade location  salary  hours_worked
# 0    Alice  Senior       RU     700            16
# 1      Bob  Junior       AU      45            10
# 2  Charlie  Middle       US      96            15
# 3    David  Senior       RU     750            65
# 4      Eve  Junior       JP      50            40
# 5    Frank  Middle       RU     120            20
# 6    Grace  Senior       US     800            70
# 7   Hannah  Senior       US    7200           175
# 8      Ivy  Middle       RU     180            50
# 9     Jack  Junior       JP      71           145

# %% [markdown]
# Задача №1.
#
# Создать новый столбец с категориями зарплат, используя сформулированные критерии:
# 1. Если зарплата меньше 50, присвоить категорию A.
# 2. Если зарплата больше 50, но меньше 100, присвоить категорию B.
# 3. Если зарплата находится в диапазоне от 100 до 500, присвоить категорию C.
# 4. Для всех остальных значений назначить категорию Other.

# %%
data['salary_category'] = 'other'
data
# Out:
#       name   grade location  salary  hours_worked salary_category
# 0    Alice  Senior       RU     700            16           other
# 1      Bob  Junior       AU      45            10           other
# 2  Charlie  Middle       US      96            15           other
# 3    David  Senior       RU     750            65           other
# 4      Eve  Junior       JP      50            40           other
# 5    Frank  Middle       RU     120            20           other
# 6    Grace  Senior       US     800            70           other
# 7   Hannah  Senior       US    7200           175           other
# 8      Ivy  Middle       RU     180            50           other
# 9     Jack  Junior       JP      71           145           other

# %%
data.loc[data['salary'] <= 50, 'salary_category'] = 'A'
data
# Out:
#       name   grade location  salary  hours_worked salary_category
# 0    Alice  Senior       RU     700            16           other
# 1      Bob  Junior       AU      45            10               A
# 2  Charlie  Middle       US      96            15           other
# 3    David  Senior       RU     750            65           other
# 4      Eve  Junior       JP      50            40               A
# 5    Frank  Middle       RU     120            20           other
# 6    Grace  Senior       US     800            70           other
# 7   Hannah  Senior       US    7200           175           other
# 8      Ivy  Middle       RU     180            50           other
# 9     Jack  Junior       JP      71           145           other

# %%
data.loc[(data['salary'] > 50) & (data['salary'] <= 100), 'salary_category'] = 'B'
data.loc[(data.salary > 100) & (data.salary <= 500), 'salary_category'] = 'C'

# %%
data
# Out:
#       name   grade location  salary  hours_worked salary_category
# 0    Alice  Senior       RU     700            16           other
# 1      Bob  Junior       AU      45            10               A
# 2  Charlie  Middle       US      96            15               B
# 3    David  Senior       RU     750            65           other
# 4      Eve  Junior       JP      50            40               A
# 5    Frank  Middle       RU     120            20               C
# 6    Grace  Senior       US     800            70           other
# 7   Hannah  Senior       US    7200           175           other
# 8      Ivy  Middle       RU     180            50               C
# 9     Jack  Junior       JP      71           145               B

# %%
bins = [-float('inf'), 50, 100, 500, float('inf')]
labels = ['A', 'B', 'C', 'other']
data['salary_category_cut'] = pd.cut(data['salary'], bins=bins, labels=labels, right=False)
data
# Out:
#       name   grade location  salary  hours_worked salary_category  \
# 0    Alice  Senior       RU     700            16           other
# 1      Bob  Junior       AU      45            10               A
# 2  Charlie  Middle       US      96            15               B
# 3    David  Senior       RU     750            65           other
# 4      Eve  Junior       JP      50            40               A
# 5    Frank  Middle       RU     120            20               C
# 6    Grace  Senior       US     800            70           other
# 7   Hannah  Senior       US    7200           175           other
# 8      Ivy  Middle       RU     180            50               C
# 9     Jack  Junior       JP      71           145               B
#
#   salary_category_cut
# 0               other
# 1                   A
# 2                   B
# 3               other
# 4                   B
# 5                   C
# 6               other
# 7               other
# 8                   C
# ...

# %% [markdown]
# Задача №2.
#
# Необходимо вывести по два сотрудника с наибольшим количеством отработанных часов для каждого уровня квалификации (грейда).

# %%
data_1 = data.groupby('grade').agg({'hours_worked': 'sum'}).reset_index()
data_1.columns = ['grade', 'total_hours_worked']
data_1
# Out:
#     grade  total_hours_worked
# 0  Junior                 195
# 1  Middle                  85
# 2  Senior                 326

# %%
top_workers_per_grade = data.groupby('grade').apply(lambda x: x.nlargest(2, 'hours_worked')).reset_index(drop=True)

top_workers_per_grade
# Out:
#      name   grade location  salary  hours_worked salary_category  \
# 0    Jack  Junior       JP      71           145               B
# 1     Eve  Junior       JP      50            40               A
# 2     Ivy  Middle       RU     180            50               C
# 3   Frank  Middle       RU     120            20               C
# 4  Hannah  Senior       US    7200           175           other
# 5   Grace  Senior       US     800            70           other
#
#   salary_category_cut
# 0                   B
# 1                   B
# 2                   C
# 3                   C
# 4               other
# 5               other

# %%
data_1_sorted = data.sort_values(by=['grade', 'hours_worked'], ascending=[True, False])
data_1_sorted
# Out:
#       name   grade location  salary  hours_worked salary_category  \
# 9     Jack  Junior       JP      71           145               B
# 4      Eve  Junior       JP      50            40               A
# 1      Bob  Junior       AU      45            10               A
# 8      Ivy  Middle       RU     180            50               C
# 5    Frank  Middle       RU     120            20               C
# 2  Charlie  Middle       US      96            15               B
# 7   Hannah  Senior       US    7200           175           other
# 6    Grace  Senior       US     800            70           other
# 3    David  Senior       RU     750            65           other
# 0    Alice  Senior       RU     700            16           other
#
#   salary_category_cut
# 9                   B
# 4                   B
# 1                   A
# 8                   C
# 5                   C
# 2                   B
# 7               other
# 6               other
# 3               other
# ...

# %%
data.nlargest(2, 'salary')
# Out:
#      name   grade location  salary  hours_worked salary_category  \
# 7  Hannah  Senior       US    7200           175           other
# 6   Grace  Senior       US     800            70           other
#
#   salary_category_cut
# 7               other
# 6               other

# %%
data.nsmallest(2, 'salary')
# Out:
#   name   grade location  salary  hours_worked salary_category  \
# 1  Bob  Junior       AU      45            10               A
# 4  Eve  Junior       JP      50            40               A
#
#   salary_category_cut
# 1                   A
# 4                   B

# %%
data
# Out:
#       name   grade location  salary  hours_worked salary_category  \
# 0    Alice  Senior       RU     700            16           other
# 1      Bob  Junior       AU      45            10               A
# 2  Charlie  Middle       US      96            15               B
# 3    David  Senior       RU     750            65           other
# 4      Eve  Junior       JP      50            40               A
# 5    Frank  Middle       RU     120            20               C
# 6    Grace  Senior       US     800            70           other
# 7   Hannah  Senior       US    7200           175           other
# 8      Ivy  Middle       RU     180            50               C
# 9     Jack  Junior       JP      71           145               B
#
#   salary_category_cut
# 0               other
# 1                   A
# 2                   B
# 3               other
# 4                   B
# 5                   C
# 6               other
# 7               other
# 8                   C
# ...

# %%
data['salary'].rank(ascending=False)
# Out:
# 0     4.0
# 1    10.0
# 2     7.0
# 3     3.0
# 4     9.0
# 5     6.0
# 6     2.0
# 7     1.0
# 8     5.0
# 9     8.0
# Name: salary, dtype: float64

# %%
data[['salary', 'grade']]
# Out:
#    salary   grade
# 0     700  Senior
# 1      45  Junior
# 2      96  Middle
# 3     750  Senior
# 4      50  Junior
# 5     120  Middle
# 6     800  Senior
# 7    7200  Senior
# 8     180  Middle
# 9      71  Junior

# %%
d = data.groupby('grade').agg({'salary': 'sum'}).reset_index()
d
# Out:
#     grade  salary
# 0  Junior     166
# 1  Middle     396
# 2  Senior    9450

# %%
d.index
# Out:
# RangeIndex(start=0, stop=3, step=1)
